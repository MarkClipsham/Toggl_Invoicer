# %%
#This code is to automate the generation of CSV from the Toggl time tracking tool in order to populate a 
#Power Bi dataset for the purposes of reporting and invoicing easily using the Toggl API.

# %%
#Importing necessary python libraries
import requests
import pandas as pd
import base64
import os
from datetime import datetime
import json

# %%
#toggl api token
toggl_api_token = '22c9bb5eb8a7c8ae391418ed3b48e0bc'
string = toggl_api_token + ':api_token'
#conversion to base64 encoding and classification of bse64 as headers variable 
headers = {
    'Authorization': 'Basic ' + base64.b64encode(string.encode('ascii')).decode("utf-8")}

#url for authorisation
auth_url = 'https://api.track.toggl.com/api/v8/me'

#calling authorisation endpoint and response as a json
auth_resp = requests.get(auth_url, headers=headers)
auth_resp_json = json.loads(auth_resp.text)
auth_resp_json
# Out:
# {'since': 1644072889,
#  'data': {'id': 6700366,
#   'api_token': '22c9bb5eb8a7c8ae391418ed3b48e0bc',
#   'default_wid': 5213492,
#   'email': 'mark.r.clipsham@gmail.com',
#   'fullname': 'Mark Clipsham',
#   'jquery_timeofday_format': 'h:i A',
#   'jquery_date_format': 'm/d/Y',
#   'timeofday_format': 'h:mm A',
#   'date_format': 'MM/DD/YYYY',
#   'store_start_and_stop_time': True,
#   'beginning_of_week': 1,
#   'language': 'en_US',
#   'image_url': 'https://assets.track.toggl.com/images/profile.png',
#   'sidebar_piechart': True,
#   'at': '2021-03-15T10:23:38+00:00',
#   'created_at': '2021-03-15T10:23:38+00:00',
#   'retention': 9,
#   'record_timeline': False,
#   'render_timeline': False,
#   'timeline_enabled': False,
#   'timeline_experiment': False,
#   'should_upgrade': True,
#   'timezone': 'Etc/UTC',
#   'openid_enabled': False,
#   'send_product_emails': True,
#   'send_weekly_report': True,
#   'send_timer_notifications': True,
#   'invitation': {},
#   'workspaces': [{'id': 5213492,
#     'name': "Mark Clipsham's workspace",
#     'profile': 0,
#     'premium': False,
#     'admin': True,
#     'default_hourly_rate': 0,
#     'default_currency': 'USD',
#     'only_admins_may_create_projects': False,
#     'only_admins_see_billable_rates': False,
#     'only_admins_see_team_dashboard': False,
#     'projects_billable_by_default': True,
#     'rounding': 1,
#     'rounding_minutes': 0,
#     'api_token': '5910ef3ecd39e23527f18962141395ae',
#     'at': '2021-03-15T10:23:38+00:00',
#     'ical_enabled': True,
#     'csv_upload': {'at': '2022-01-20 19:39:37.121371+00', 'log_id': 207199}}],
#   'duration_format': 'improved'}}

# %%
#time entries url
time_entries_url = 'https://api.track.toggl.com/reports/api/v2/details?'

#request parameters
user_agent = auth_resp_json['data']['email']
workspaces_list = auth_resp_json['data']['workspaces']
workspaces_dict = workspaces_list[0]
workspace_id = workspaces_dict['id']
user_agent_param = 'user_agent='+user_agent
workspace_id_param = 'workspace_id='+str(workspace_id)
since = datetime.strptime('Sun, 01 Aug 2021 12:14:05', '%a, %d %b %Y %H:%M:%S')
since_iso = since.isoformat()
since_param = 'since='+since_iso

#request for first page of data
page_param1 = 'page=1'
combined_params1 = workspace_id_param+'&'+since_param+'&'+user_agent_param
time_entries_page1 = requests.get(time_entries_url,headers=headers, params = combined_params1)
time_entries_data_page1 = time_entries_page1.json()
time_entries_data_page1
# Out:
# {'total_grand': 483219000,
#  'total_billable': None,
#  'total_currencies': [{'currency': None, 'amount': None}],
#  'total_count': 82,
#  'per_page': 50,
#  'data': [{'id': 2355603349,
#    'pid': 179019829,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'DAM KPIs',
#    'start': '2022-02-04T13:10:34+00:00',
#    'end': '2022-02-04T15:32:21+00:00',
#    'updated': '2022-02-04T15:32:23+00:00',
#    'dur': 8507000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'PBi Support',
#    'project_color': '0',
#    'project_hex_color': '#566614',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2355118585,
#    'pid': 178668430,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'AST Reporting build',
#    'start': '2022-02-04T07:42:40+00:00',
#    'end': '2022-02-04T12:00:40+00:00',
#    'updated': '2022-02-04T13:10:14+00:00',
#    'dur': 15480000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'AST Revamp',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2355096417,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'General admin',
#    'start': '2022-02-04T07:23:27+00:00',
#    'end': '2022-02-04T07:42:39+00:00',
#    'updated': '2022-02-04T07:42:41+00:00',
#    'dur': 1152000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2355095997,
#    'pid': 178668430,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'AST Reporting build',
#    'start': '2022-02-04T07:23:03+00:00',
#    'end': '2022-02-04T07:23:27+00:00',
#    'updated': '2022-02-04T07:23:28+00:00',
#    'dur': 24000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'AST Revamp',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2354071676,
#    'pid': 178668430,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'AST Reporting build',
#    'start': '2022-02-03T15:23:08+00:00',
#    'end': '2022-02-03T16:22:11+00:00',
#    'updated': '2022-02-03T16:22:12+00:00',
#    'dur': 3543000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'AST Revamp',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2353948500,
#    'pid': None,
#    'tid': None,
#    'uid': 6700366,
#    'description': '',
#    'start': '2022-02-03T14:26:16+00:00',
#    'end': '2022-02-03T15:23:08+00:00',
#    'updated': '2022-02-03T15:23:09+00:00',
#    'dur': 3412000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': None,
#    'project': None,
#    'project_color': '0',
#    'project_hex_color': None,
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2353842337,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'General admin',
#    'start': '2022-02-03T13:34:16+00:00',
#    'end': '2022-02-03T14:26:14+00:00',
#    'updated': '2022-02-03T14:26:14+00:00',
#    'dur': 3118000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2353662604,
#    'pid': 178668430,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'AST Reporting build',
#    'start': '2022-02-03T09:00:46+00:00',
#    'end': '2022-02-03T12:11:29+00:00',
#    'updated': '2022-02-03T12:11:31+00:00',
#    'dur': 11443000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'AST Revamp',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2353267244,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'General admin',
#    'start': '2022-02-03T07:30:51+00:00',
#    'end': '2022-02-03T09:00:51+00:00',
#    'updated': '2022-02-03T11:49:43+00:00',
#    'dur': 5400000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2352220068,
#    'pid': 179076630,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'DAM KPI meeting',
#    'start': '2022-02-02T15:00:27+00:00',
#    'end': '2022-02-02T15:46:37+00:00',
#    'updated': '2022-02-02T15:46:38+00:00',
#    'dur': 2770000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': "DAM KPI's",
#    'project_color': '0',
#    'project_hex_color': '#d94182',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2351915193,
#    'pid': 178668430,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'AST Reporting build',
#    'start': '2022-02-02T13:26:05+00:00',
#    'end': '2022-02-02T13:26:07+00:00',
#    'updated': '2022-02-02T13:26:07+00:00',
#    'dur': 2000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'AST Revamp',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2351915267,
#    'pid': 178668430,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'AST Reporting build',
#    'start': '2022-02-02T13:00:07+00:00',
#    'end': '2022-02-02T15:01:18+00:00',
#    'updated': '2022-02-02T15:01:19+00:00',
#    'dur': 7271000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'AST Revamp',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2351714313,
#    'pid': 178668430,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'AST Reporting build',
#    'start': '2022-02-02T11:28:52+00:00',
#    'end': '2022-02-02T12:00:52+00:00',
#    'updated': '2022-02-02T13:25:48+00:00',
#    'dur': 1920000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'AST Revamp',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2351666803,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'General admin',
#    'start': '2022-02-02T10:58:45+00:00',
#    'end': '2022-02-02T11:28:52+00:00',
#    'updated': '2022-02-02T11:28:52+00:00',
#    'dur': 1807000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2351600996,
#    'pid': 178668430,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'AST Reporting build',
#    'start': '2022-02-02T10:19:29+00:00',
#    'end': '2022-02-02T10:58:45+00:00',
#    'updated': '2022-02-02T10:58:45+00:00',
#    'dur': 2356000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'AST Revamp',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2351420297,
#    'pid': 179019829,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Class Disruption DB',
#    'start': '2022-02-02T08:35:04+00:00',
#    'end': '2022-02-02T10:19:09+00:00',
#    'updated': '2022-02-02T10:19:09+00:00',
#    'dur': 6245000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'PBi Support',
#    'project_color': '0',
#    'project_hex_color': '#566614',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2351314971,
#    'pid': 179004643,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'SITs Migration DB',
#    'start': '2022-02-02T07:24:40+00:00',
#    'end': '2022-02-02T08:35:00+00:00',
#    'updated': '2022-02-02T08:35:00+00:00',
#    'dur': 4220000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'SITs Mig Dashboard',
#    'project_color': '0',
#    'project_hex_color': '#9e5bd9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2350370564,
#    'pid': 179004643,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'SITs Migration DB',
#    'start': '2022-02-01T16:00:29+00:00',
#    'end': '2022-02-01T16:39:29+00:00',
#    'updated': '2022-02-01T16:39:45+00:00',
#    'dur': 2340000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'SITs Mig Dashboard',
#    'project_color': '0',
#    'project_hex_color': '#9e5bd9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2350102124,
#    'pid': 179019829,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Class Disruption DB',
#    'start': '2022-02-01T14:40:14+00:00',
#    'end': '2022-02-01T16:00:14+00:00',
#    'updated': '2022-02-01T16:39:23+00:00',
#    'dur': 4800000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'PBi Support',
#    'project_color': '0',
#    'project_hex_color': '#566614',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2350095354,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'General admin',
#    'start': '2022-02-01T14:37:10+00:00',
#    'end': '2022-02-01T14:40:00+00:00',
#    'updated': '2022-02-01T14:39:40+00:00',
#    'dur': 170000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2349860862,
#    'pid': 178668430,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'AST Reporting Catch up',
#    'start': '2022-02-01T12:48:46+00:00',
#    'end': '2022-02-01T13:20:46+00:00',
#    'updated': '2022-02-02T10:20:00+00:00',
#    'dur': 1920000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'AST Revamp',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2349774489,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Course Committee - PBI Solutions (Meeting)',
#    'start': '2022-02-01T11:59:09+00:00',
#    'end': '2022-02-01T12:48:33+00:00',
#    'updated': '2022-02-01T12:48:14+00:00',
#    'dur': 2964000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2349677604,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Sprint Planning/Finishing',
#    'start': '2022-02-01T10:59:50+00:00',
#    'end': '2022-02-01T11:58:38+00:00',
#    'updated': '2022-02-01T11:58:19+00:00',
#    'dur': 3528000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2349642264,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'General admin',
#    'start': '2022-02-01T10:20:32+00:00',
#    'end': '2022-02-01T10:59:36+00:00',
#    'updated': '2022-02-01T10:59:16+00:00',
#    'dur': 2344000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2349572274,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Scope meeting - Dot Dickson',
#    'start': '2022-02-01T09:58:30+00:00',
#    'end': '2022-02-01T10:20:30+00:00',
#    'updated': '2022-02-01T10:38:07+00:00',
#    'dur': 1320000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2349500274,
#    'pid': 179004643,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'SITs Migration DB',
#    'start': '2022-02-01T09:18:32+00:00',
#    'end': '2022-02-01T09:58:25+00:00',
#    'updated': '2022-02-01T09:58:05+00:00',
#    'dur': 2393000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'SITs Mig Dashboard',
#    'project_color': '0',
#    'project_hex_color': '#9e5bd9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2349434185,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'General admin',
#    'start': '2022-02-01T07:35:23+00:00',
#    'end': '2022-02-01T09:18:25+00:00',
#    'updated': '2022-02-01T09:18:05+00:00',
#    'dur': 6182000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2347728360,
#    'pid': None,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Build - Power Bi report for automated toggl invoicing',
#    'start': '2022-01-31T12:10:10+00:00',
#    'end': '2022-01-31T13:21:20+00:00',
#    'updated': '2022-01-31T13:21:18+00:00',
#    'dur': 4270000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': None,
#    'project': None,
#    'project_color': '0',
#    'project_hex_color': None,
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2347630793,
#    'pid': 178897182,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Toggl API dealing with paginated data',
#    'start': '2022-01-31T11:12:35+00:00',
#    'end': '2022-01-31T12:09:43+00:00',
#    'updated': '2022-01-31T12:09:41+00:00',
#    'dur': 3428000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'Toggl Tracker/Automated Invoicing',
#    'project_color': '0',
#    'project_hex_color': '#525266',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2347610450,
#    'pid': 178897182,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Toggl API Calling',
#    'start': '2022-01-31T10:23:55+00:00',
#    'end': '2022-01-31T11:12:18+00:00',
#    'updated': '2022-01-31T11:12:16+00:00',
#    'dur': 2903000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'Toggl Tracker/Automated Invoicing',
#    'project_color': '0',
#    'project_hex_color': '#525266',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2346651999,
#    'pid': 178897182,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Toggl API data to useable format',
#    'start': '2022-01-30T11:35:56+00:00',
#    'end': '2022-01-30T12:17:05+00:00',
#    'updated': '2022-01-30T12:17:04+00:00',
#    'dur': 2469000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'Toggl Tracker/Automated Invoicing',
#    'project_color': '0',
#    'project_hex_color': '#525266',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2346411641,
#    'pid': None,
#    'tid': None,
#    'uid': 6700366,
#    'description': '',
#    'start': '2022-01-29T18:11:02+00:00',
#    'end': '2022-01-29T18:47:52+00:00',
#    'updated': '2022-01-29T18:47:52+00:00',
#    'dur': 2210000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': None,
#    'project': None,
#    'project_color': '0',
#    'project_hex_color': None,
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2346314638,
#    'pid': 178897182,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Toggl API Calling',
#    'start': '2022-01-29T13:42:55+00:00',
#    'end': '2022-01-29T15:10:28+00:00',
#    'updated': '2022-01-29T15:10:28+00:00',
#    'dur': 5253000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'Toggl Tracker/Automated Invoicing',
#    'project_color': '0',
#    'project_hex_color': '#525266',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2346274155,
#    'pid': 178897182,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Toggl API Calling',
#    'start': '2022-01-29T11:28:48+00:00',
#    'end': '2022-01-29T12:36:44+00:00',
#    'updated': '2022-01-29T12:36:43+00:00',
#    'dur': 4076000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'Toggl Tracker/Automated Invoicing',
#    'project_color': '0',
#    'project_hex_color': '#525266',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2345433620,
#    'pid': 178897182,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Toggl API Calling',
#    'start': '2022-01-28T14:53:35+00:00',
#    'end': '2022-01-28T16:28:35+00:00',
#    'updated': '2022-01-29T11:28:37+00:00',
#    'dur': 5700000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'Toggl Tracker/Automated Invoicing',
#    'project_color': '0',
#    'project_hex_color': '#525266',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2339528968,
#    'pid': 178767529,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Net worth tracking',
#    'start': '2022-01-25T11:23:00+00:00',
#    'end': '2022-01-25T14:15:00+00:00',
#    'updated': '2022-01-28T14:53:14+00:00',
#    'dur': 10320000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'Self',
#    'project_color': '0',
#    'project_hex_color': '#9e5bd9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2338046349,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Class Disruption DB',
#    'start': '2022-01-24T15:30:06+00:00',
#    'end': '2022-01-24T16:01:45+00:00',
#    'updated': '2022-01-24T16:21:33+00:00',
#    'dur': 1899000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2337906610,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Admin email catch up',
#    'start': '2022-01-24T14:30:18+00:00',
#    'end': '2022-01-24T15:29:46+00:00',
#    'updated': '2022-01-24T15:29:38+00:00',
#    'dur': 3568000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2337735560,
#    'pid': 178720164,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'SITS Testing (Suki) Jira Reporting',
#    'start': '2022-01-24T13:10:27+00:00',
#    'end': '2022-01-24T14:30:11+00:00',
#    'updated': '2022-01-24T14:30:03+00:00',
#    'dur': 4784000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'SITs Testing Jira Reporting',
#    'project_color': '0',
#    'project_hex_color': '#c9806b',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2337339822,
#    'pid': 178720164,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'SITS Testing (Suki) Jira Reporting',
#    'start': '2022-01-24T09:22:59+00:00',
#    'end': '2022-01-24T13:10:11+00:00',
#    'updated': '2022-01-24T13:10:03+00:00',
#    'dur': 13632000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'SITs Testing Jira Reporting',
#    'project_color': '0',
#    'project_hex_color': '#c9806b',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2337330591,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Admin email catch up',
#    'start': '2022-01-24T09:17:59+00:00',
#    'end': '2022-01-24T09:22:59+00:00',
#    'updated': '2022-01-24T09:22:52+00:00',
#    'dur': 300000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2337329980,
#    'pid': 178720164,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'SITS Testing (Suki) Jira Reporting',
#    'start': '2022-01-24T09:17:39+00:00',
#    'end': '2022-01-24T09:17:58+00:00',
#    'updated': '2022-01-24T09:17:51+00:00',
#    'dur': 19000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'SITs Testing Jira Reporting',
#    'project_color': '0',
#    'project_hex_color': '#c9806b',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2337270646,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Morning Meetings',
#    'start': '2022-01-24T08:46:18+00:00',
#    'end': '2022-01-24T09:17:31+00:00',
#    'updated': '2022-01-24T09:17:23+00:00',
#    'dur': 1873000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2337219579,
#    'pid': 178720164,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'SITS Testing (Suki) Jira Reporting',
#    'start': '2022-01-24T08:16:40+00:00',
#    'end': '2022-01-24T08:46:02+00:00',
#    'updated': '2022-01-24T08:45:54+00:00',
#    'dur': 1762000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'SITs Testing Jira Reporting',
#    'project_color': '0',
#    'project_hex_color': '#c9806b',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2337171145,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Admin email catch up',
#    'start': '2022-01-24T07:30:57+00:00',
#    'end': '2022-01-24T08:16:40+00:00',
#    'updated': '2022-01-24T08:16:32+00:00',
#    'dur': 2743000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2335245794,
#    'pid': 178675988,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Jira reporting for rob',
#    'start': '2022-01-21T13:39:53+00:00',
#    'end': '2022-01-21T15:50:00+00:00',
#    'updated': '2022-01-21T16:01:20+00:00',
#    'dur': 7807000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Jura reporting',
#    'project_color': '0',
#    'project_hex_color': '#d94182',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2335242391,
#    'pid': 178675975,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Corporate pbi support',
#    'start': '2022-01-21T13:00:00+00:00',
#    'end': '2022-01-21T13:38:30+00:00',
#    'updated': '2022-01-21T13:39:50+00:00',
#    'dur': 2310000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Corporate app dashboard',
#    'project_color': '0',
#    'project_hex_color': '#e36a00',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334763430,
#    'pid': 178668430,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'AST reporting revamp',
#    'start': '2022-01-21T08:19:00+00:00',
#    'end': '2022-01-21T12:14:00+00:00',
#    'updated': '2022-01-21T13:38:25+00:00',
#    'dur': 14100000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'AST Revamp',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334762556,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'General admin',
#    'start': '2022-01-21T07:30:34+00:00',
#    'end': '2022-01-21T08:19:00+00:00',
#    'updated': '2022-01-21T08:20:44+00:00',
#    'dur': 2906000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334193943,
#    'pid': 178651855,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Exporting data with python through Toggl API',
#    'start': '2022-01-20T20:31:31+00:00',
#    'end': '2022-01-20T22:39:58+00:00',
#    'updated': '2022-01-21T08:22:16+00:00',
#    'dur': 7707000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'ABC - Finance',
#    'project': 'ABC Toggl Tracker',
#    'project_color': '0',
#    'project_hex_color': '#2da608',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []}]}

# %%
#request for second page of data
page_param2 = 'page=2'
combined_params2 = workspace_id_param+'&'+since_param+'&'+user_agent_param+'&'+page_param2
time_entries_page2 = requests.get(time_entries_url,headers=headers, params = combined_params2)
time_entries_data_page2 = time_entries_page2.json()
time_entries_data_page2
# Out:
# {'total_grand': 483219000,
#  'total_billable': None,
#  'total_currencies': [{'currency': None, 'amount': None}],
#  'total_count': 82,
#  'per_page': 50,
#  'data': [{'id': 2334190852,
#    'pid': 178651855,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Populating Data',
#    'start': '2022-01-20T20:29:21+00:00',
#    'end': '2022-01-20T20:31:14+00:00',
#    'updated': '2022-01-20T20:31:14+00:00',
#    'dur': 113000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'ABC - Finance',
#    'project': 'ABC Toggl Tracker',
#    'project_color': '0',
#    'project_hex_color': '#2da608',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334138080,
#    'pid': 178651855,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Initial Client Meeting',
#    'start': '2022-01-20T19:49:03+00:00',
#    'end': '2022-01-20T20:29:16+00:00',
#    'updated': '2022-01-21T08:22:25+00:00',
#    'dur': 2413000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'ABC - Finance',
#    'project': 'ABC Toggl Tracker',
#    'project_color': '0',
#    'project_hex_color': '#2da608',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334064647,
#    'pid': 178651855,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Populating Data',
#    'start': '2022-01-20T18:55:52+00:00',
#    'end': '2022-01-20T19:48:51+00:00',
#    'updated': '2022-01-20T19:48:51+00:00',
#    'dur': 3179000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'ABC - Finance',
#    'project': 'ABC Toggl Tracker',
#    'project_color': '0',
#    'project_hex_color': '#2da608',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334064114,
#    'pid': 178651855,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Populating Data',
#    'start': '2022-01-20T18:55:29+00:00',
#    'end': '2022-01-20T18:55:42+00:00',
#    'updated': '2022-01-20T18:55:50+00:00',
#    'dur': 13000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'ABC - Finance',
#    'project': 'ABC Toggl Tracker',
#    'project_color': '0',
#    'project_hex_color': '#2da608',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334040588,
#    'pid': 178651855,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Scope - Toggl Tracker',
#    'start': '2022-01-20T18:38:17+00:00',
#    'end': '2022-01-20T18:44:27+00:00',
#    'updated': '2022-01-20T18:44:36+00:00',
#    'dur': 370000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'ABC - Finance',
#    'project': 'ABC Toggl Tracker',
#    'project_color': '0',
#    'project_hex_color': '#2da608',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126182,
#    'pid': 178654084,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Training Team Leads',
#    'start': '2021-11-19T15:23:00+00:00',
#    'end': '2021-11-19T16:48:22+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 5122000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'SW Learning - Portfolio',
#    'project_color': '0',
#    'project_hex_color': '#465bb3',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126181,
#    'pid': 178654084,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Training Super users',
#    'start': '2021-11-16T11:54:00+00:00',
#    'end': '2021-11-16T15:16:05+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 12125000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'SW Learning - Portfolio',
#    'project_color': '0',
#    'project_hex_color': '#465bb3',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126180,
#    'pid': 178654084,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Presentation to SLT',
#    'start': '2021-11-13T14:22:00+00:00',
#    'end': '2021-11-13T19:36:55+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 18895000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'SW Learning - Portfolio',
#    'project_color': '0',
#    'project_hex_color': '#465bb3',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126178,
#    'pid': 178654084,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Delivery',
#    'start': '2021-11-10T15:23:00+00:00',
#    'end': '2021-11-10T16:21:25+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 3505000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'SW Learning - Portfolio',
#    'project_color': '0',
#    'project_hex_color': '#465bb3',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126177,
#    'pid': 178654084,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Presentation to Arno + Team',
#    'start': '2021-11-07T11:54:00+00:00',
#    'end': '2021-11-07T16:15:33+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 15693000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'SW Learning - Portfolio',
#    'project_color': '0',
#    'project_hex_color': '#465bb3',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126176,
#    'pid': 178654084,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Delivery',
#    'start': '2021-11-04T10:23:52+00:00',
#    'end': '2021-11-04T12:36:47+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 7975000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'SW Learning - Portfolio',
#    'project_color': '0',
#    'project_hex_color': '#465bb3',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126175,
#    'pid': 178654084,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Meeting With Arno',
#    'start': '2021-11-01T10:23:52+00:00',
#    'end': '2021-11-01T11:49:14+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 5122000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'SW Learning - Portfolio',
#    'project_color': '0',
#    'project_hex_color': '#465bb3',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126174,
#    'pid': 178654084,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Feedback Tasks',
#    'start': '2021-10-29T17:00:00+00:00',
#    'end': '2021-10-29T19:12:55+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 7975000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'SW Learning - Portfolio',
#    'project_color': '0',
#    'project_hex_color': '#465bb3',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126172,
#    'pid': 178654084,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Visualisation',
#    'start': '2021-10-26T08:14:00+00:00',
#    'end': '2021-10-26T09:12:25+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 3505000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'SW Learning - Portfolio',
#    'project_color': '0',
#    'project_hex_color': '#465bb3',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126171,
#    'pid': 178654084,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Validating',
#    'start': '2021-10-23T14:22:00+00:00',
#    'end': '2021-10-23T18:43:33+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 15693000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'SW Learning - Portfolio',
#    'project_color': '0',
#    'project_hex_color': '#465bb3',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126170,
#    'pid': 178654084,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Initial Code',
#    'start': '2021-10-20T15:23:00+00:00',
#    'end': '2021-10-20T16:21:25+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 3505000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'SW Learning - Portfolio',
#    'project_color': '0',
#    'project_hex_color': '#465bb3',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126169,
#    'pid': 178654084,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Initial Code',
#    'start': '2021-10-17T11:54:00+00:00',
#    'end': '2021-10-17T16:15:33+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 15693000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'SW Learning - Portfolio',
#    'project_color': '0',
#    'project_hex_color': '#465bb3',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126168,
#    'pid': 178654084,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Data Exploration',
#    'start': '2021-10-14T10:23:52+00:00',
#    'end': '2021-10-14T12:36:47+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 7975000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'SW Learning - Portfolio',
#    'project_color': '0',
#    'project_hex_color': '#465bb3',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126167,
#    'pid': 178654084,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Meeting Clients',
#    'start': '2021-10-11T17:00:00+00:00',
#    'end': '2021-10-11T22:14:55+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 18895000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'SW Learning - Portfolio',
#    'project_color': '0',
#    'project_hex_color': '#465bb3',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126166,
#    'pid': 178653313,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Presentation to SLT',
#    'start': '2021-10-08T08:14:00+00:00',
#    'end': '2021-10-08T09:12:25+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 3505000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'JRC',
#    'project': 'JRC Finance Analysis',
#    'project_color': '0',
#    'project_hex_color': '#991102',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126165,
#    'pid': 178653313,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Delivery',
#    'start': '2021-10-05T14:22:00+00:00',
#    'end': '2021-10-05T18:43:33+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 15693000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'JRC',
#    'project': 'JRC Finance Analysis',
#    'project_color': '0',
#    'project_hex_color': '#991102',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126164,
#    'pid': 178653313,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Presentation to Arno + Team',
#    'start': '2021-10-02T11:54:00+00:00',
#    'end': '2021-10-02T14:06:55+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 7975000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'JRC',
#    'project': 'JRC Finance Analysis',
#    'project_color': '0',
#    'project_hex_color': '#991102',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126163,
#    'pid': 178653313,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Delivery',
#    'start': '2021-09-29T10:23:52+00:00',
#    'end': '2021-09-29T11:22:17+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 3505000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'JRC',
#    'project': 'JRC Finance Analysis',
#    'project_color': '0',
#    'project_hex_color': '#991102',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126161,
#    'pid': 178653313,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Meeting With Arno',
#    'start': '2021-09-26T17:00:00+00:00',
#    'end': '2021-09-26T21:21:33+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 15693000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'JRC',
#    'project': 'JRC Finance Analysis',
#    'project_color': '0',
#    'project_hex_color': '#991102',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126160,
#    'pid': 178653313,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Feedback Tasks',
#    'start': '2021-09-23T08:14:00+00:00',
#    'end': '2021-09-23T10:26:55+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 7975000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'JRC',
#    'project': 'JRC Finance Analysis',
#    'project_color': '0',
#    'project_hex_color': '#991102',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126159,
#    'pid': 178653313,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Visualisation',
#    'start': '2021-09-20T15:23:00+00:00',
#    'end': '2021-09-20T16:48:22+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 5122000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'JRC',
#    'project': 'JRC Finance Analysis',
#    'project_color': '0',
#    'project_hex_color': '#991102',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126158,
#    'pid': 178653313,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Validating',
#    'start': '2021-09-17T11:54:00+00:00',
#    'end': '2021-09-17T15:16:05+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 12125000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'JRC',
#    'project': 'JRC Finance Analysis',
#    'project_color': '0',
#    'project_hex_color': '#991102',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126156,
#    'pid': 178653313,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Initial Code',
#    'start': '2021-09-14T10:23:52+00:00',
#    'end': '2021-09-14T15:38:47+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 18895000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'JRC',
#    'project': 'JRC Finance Analysis',
#    'project_color': '0',
#    'project_hex_color': '#991102',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126155,
#    'pid': 178653313,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Initial Code',
#    'start': '2021-09-11T17:00:00+00:00',
#    'end': '2021-09-11T17:58:25+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 3505000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'JRC',
#    'project': 'JRC Finance Analysis',
#    'project_color': '0',
#    'project_hex_color': '#991102',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126154,
#    'pid': 178653313,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Data Exploration',
#    'start': '2021-09-08T08:14:00+00:00',
#    'end': '2021-09-08T12:35:33+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 15693000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'JRC',
#    'project': 'JRC Finance Analysis',
#    'project_color': '0',
#    'project_hex_color': '#991102',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126153,
#    'pid': 178653313,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Meeting Clients',
#    'start': '2021-09-05T14:22:00+00:00',
#    'end': '2021-09-05T16:34:55+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 7975000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'JRC',
#    'project': 'JRC Finance Analysis',
#    'project_color': '0',
#    'project_hex_color': '#991102',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126152,
#    'pid': 178651869,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Summary presentation on first 3 months of use to SLT',
#    'start': '2021-08-02T15:23:00+00:00',
#    'end': '2021-08-02T16:48:22+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 5122000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'ABC - Finance',
#    'project': 'ABC RandomForest',
#    'project_color': '0',
#    'project_hex_color': '#9e5bd9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []}]}

# %%
#converting returned data to pandas dataframe
data_page1 = time_entries_data_page1['data']
df_page1 = pd.DataFrame(data_page1)
data_page2 = time_entries_data_page2['data']
df_page2 = pd.DataFrame(data_page2)

#dropping un-used columns
df_page1 = df_page1.drop(columns=['use_stop', 'task', 'billable', 'is_billable', 'cur', 'tags','project_color'])
df_page2 = df_page2.drop(columns=['use_stop', 'task', 'billable', 'is_billable', 'cur', 'tags','project_color'])

# %%
#appending pages into a single dataframe
data = df_page1.append(df_page2, ignore_index=True)
data
# Out:
#             id          pid   tid      uid  \
# 0   2355603349  179019829.0  None  6700366
# 1   2355118585  178668430.0  None  6700366
# 2   2355096417  178668409.0  None  6700366
# 3   2355095997  178668430.0  None  6700366
# 4   2354071676  178668430.0  None  6700366
# ..         ...          ...   ...      ...
# 77  2334126156  178653313.0  None  6700366
# 78  2334126155  178653313.0  None  6700366
# 79  2334126154  178653313.0  None  6700366
# 80  2334126153  178653313.0  None  6700366
# 81  2334126152  178651869.0  None  6700366
#
#                                           description  \
# 0                                            DAM KPIs
# 1                                 AST Reporting build
# 2                                       General admin
# 3                                 AST Reporting build
# 4                                 AST Reporting build
# ..                                                ...
# 77                                       Initial Code
# 78                                       Initial Code
# 79                                   Data Exploration
# 80                                    Meeting Clients
# 81  Summary presentation on first 3 months of use ...
#
#                         start                        end  \
# 0   2022-02-04T13:10:34+00:00  2022-02-04T15:32:21+00:00
# 1   2022-02-04T07:42:40+00:00  2022-02-04T12:00:40+00:00
# 2   2022-02-04T07:23:27+00:00  2022-02-04T07:42:39+00:00
# 3   2022-02-04T07:23:03+00:00  2022-02-04T07:23:27+00:00
# 4   2022-02-03T15:23:08+00:00  2022-02-03T16:22:11+00:00
# ..                        ...                        ...
# 77  2021-09-14T10:23:52+00:00  2021-09-14T15:38:47+00:00
# 78  2021-09-11T17:00:00+00:00  2021-09-11T17:58:25+00:00
# 79  2021-09-08T08:14:00+00:00  2021-09-08T12:35:33+00:00
# 80  2021-09-05T14:22:00+00:00  2021-09-05T16:34:55+00:00
# 81  2021-08-02T15:23:00+00:00  2021-08-02T16:48:22+00:00
#
#                       updated       dur           user            client  \
# 0   2022-02-04T15:32:23+00:00   8507000  Mark Clipsham  Arden University
# 1   2022-02-04T13:10:14+00:00  15480000  Mark Clipsham  Arden University
# 2   2022-02-04T07:42:41+00:00   1152000  Mark Clipsham  Arden University
# 3   2022-02-04T07:23:28+00:00     24000  Mark Clipsham  Arden University
# 4   2022-02-03T16:22:12+00:00   3543000  Mark Clipsham  Arden University
# ..                        ...       ...            ...               ...
# 77  2022-01-20T19:39:53+00:00  18895000  Mark Clipsham               JRC
# 78  2022-01-20T19:39:53+00:00   3505000  Mark Clipsham               JRC
# 79  2022-01-20T19:39:53+00:00  15693000  Mark Clipsham               JRC
# 80  2022-01-20T19:39:53+00:00   7975000  Mark Clipsham               JRC
# 81  2022-01-20T19:39:53+00:00   5122000  Mark Clipsham     ABC - Finance
#
#                  project project_hex_color
# 0            PBi Support           #566614
# 1             AST Revamp           #0b83d9
# 2      Arden Uni General           #0b83d9
# 3             AST Revamp           #0b83d9
# 4             AST Revamp           #0b83d9
# ..                   ...               ...
# 77  JRC Finance Analysis           #991102
# 78  JRC Finance Analysis           #991102
# 79  JRC Finance Analysis           #991102
# 80  JRC Finance Analysis           #991102
# 81      ABC RandomForest           #9e5bd9
#
# [82 rows x 13 columns]

# %%
#pandas dataframe to csv file
csv = data.to_csv(r'C:\Users\markr\Documents\Portfolio\Toggl Tracker\output.csv')
