# %%
#This code is to automate the generation of CSV from the Toggl time tracking tool in order to populate a 
#Power Bi dataset for the purposes of reporting and invoicing easily using the Toggl API.

# %%
#Importing necessary python libraries
import requests
import pandas as pd
import base64
import os
from datetime import datetime
import json

# %%
#toggl api token
toggl_api_token = '22c9bb5eb8a7c8ae391418ed3b48e0bc'
string = toggl_api_token + ':api_token'
#conversion to base64 encoding and classification of bse64 as headers variable 
headers = {
    'Authorization': 'Basic ' + base64.b64encode(string.encode('ascii')).decode("utf-8")}

#url for authorisation
auth_url = 'https://api.track.toggl.com/api/v8/me'

#calling authorisation endpoint and response as a json
auth_resp = requests.get(auth_url, headers=headers)
auth_resp_json = json.loads(auth_resp.text)
auth_resp_json
# Out:
# {'since': 1644788082,
#  'data': {'id': 6700366,
#   'api_token': '22c9bb5eb8a7c8ae391418ed3b48e0bc',
#   'default_wid': 5213492,
#   'email': 'mark.r.clipsham@gmail.com',
#   'fullname': 'Mark Clipsham',
#   'jquery_timeofday_format': 'h:i A',
#   'jquery_date_format': 'm/d/Y',
#   'timeofday_format': 'h:mm A',
#   'date_format': 'MM/DD/YYYY',
#   'store_start_and_stop_time': True,
#   'beginning_of_week': 1,
#   'language': 'en_US',
#   'image_url': 'https://assets.track.toggl.com/images/profile.png',
#   'sidebar_piechart': True,
#   'at': '2021-03-15T10:23:38+00:00',
#   'created_at': '2021-03-15T10:23:38+00:00',
#   'retention': 9,
#   'record_timeline': False,
#   'should_upgrade': True,
#   'timezone': 'Etc/UTC',
#   'openid_enabled': False,
#   'send_product_emails': True,
#   'send_weekly_report': True,
#   'send_timer_notifications': True,
#   'invitation': {},
#   'workspaces': [{'id': 5213492,
#     'name': "Mark Clipsham's workspace",
#     'profile': 0,
#     'premium': False,
#     'admin': True,
#     'default_hourly_rate': 0,
#     'default_currency': 'USD',
#     'only_admins_may_create_projects': False,
#     'only_admins_see_billable_rates': False,
#     'only_admins_see_team_dashboard': False,
#     'projects_billable_by_default': True,
#     'rounding': 1,
#     'rounding_minutes': 0,
#     'api_token': '5910ef3ecd39e23527f18962141395ae',
#     'at': '2021-03-15T10:23:38+00:00',
#     'ical_enabled': True,
#     'csv_upload': {'at': '2022-01-20 19:39:37.121371+00', 'log_id': 207199}}],
#   'duration_format': 'improved'}}

# %%
#time entries url
time_entries_url = 'https://api.track.toggl.com/reports/api/v2/details?'

#request parameters
user_agent = auth_resp_json['data']['email']
workspaces_list = auth_resp_json['data']['workspaces']
workspaces_dict = workspaces_list[0]
workspace_id = workspaces_dict['id']
user_agent_param = 'user_agent='+user_agent
workspace_id_param = 'workspace_id='+str(workspace_id)
since = datetime.strptime('Sun, 01 Aug 2021 12:14:05', '%a, %d %b %Y %H:%M:%S')
since_iso = since.isoformat()
since_param = 'since='+since_iso

#request for first page of data
page_param1 = 'page=1'
combined_params1 = workspace_id_param+'&'+since_param+'&'+user_agent_param
time_entries_page1 = requests.get(time_entries_url,headers=headers, params = combined_params1)
time_entries_data_page1 = time_entries_page1.json()
time_entries_data_page1
# Out:
# {'total_grand': 583420000,
#  'total_billable': None,
#  'total_currencies': [{'currency': None, 'amount': None}],
#  'total_count': 116,
#  'per_page': 50,
#  'data': [{'id': 2364428553,
#    'pid': 179019829,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Scoping Automated Finance Snapshot Solution',
#    'start': '2022-02-10T15:36:51+00:00',
#    'end': '2022-02-10T16:03:08+00:00',
#    'updated': '2022-02-10T16:03:07+00:00',
#    'dur': 1577000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'PBi Support',
#    'project_color': '0',
#    'project_hex_color': '#566614',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2364368122,
#    'pid': 178675988,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Long term Jira Reporting Plan',
#    'start': '2022-02-10T15:07:35+00:00',
#    'end': '2022-02-10T15:36:39+00:00',
#    'updated': '2022-02-10T15:36:37+00:00',
#    'dur': 1744000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Jira reporting',
#    'project_color': '0',
#    'project_hex_color': '#d94182',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2364367209,
#    'pid': 179367366,
#    'tid': None,
#    'uid': 6700366,
#    'description': "Scoping Strategic KPI's",
#    'start': '2022-02-10T13:00:07+00:00',
#    'end': '2022-02-10T15:07:07+00:00',
#    'updated': '2022-02-10T15:07:19+00:00',
#    'dur': 7620000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': "Strategic KPI's",
#    'project_color': '0',
#    'project_hex_color': '#e36a00',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2363666000,
#    'pid': 179367366,
#    'tid': None,
#    'uid': 6700366,
#    'description': "Scoping Strategic KPI's",
#    'start': '2022-02-10T08:29:28+00:00',
#    'end': '2022-02-10T12:00:28+00:00',
#    'updated': '2022-02-10T15:06:47+00:00',
#    'dur': 12660000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': "Strategic KPI's",
#    'project_color': '0',
#    'project_hex_color': '#e36a00',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2363649397,
#    'pid': 178675988,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Long term Jira Reporting Plan',
#    'start': '2022-02-10T08:18:48+00:00',
#    'end': '2022-02-10T08:29:28+00:00',
#    'updated': '2022-02-10T08:29:25+00:00',
#    'dur': 640000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Jira reporting',
#    'project_color': '0',
#    'project_hex_color': '#d94182',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2363592320,
#    'pid': 179367366,
#    'tid': None,
#    'uid': 6700366,
#    'description': "Scoping Strategic KPI's",
#    'start': '2022-02-10T07:41:38+00:00',
#    'end': '2022-02-10T08:18:30+00:00',
#    'updated': '2022-02-10T08:18:27+00:00',
#    'dur': 2212000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': "Strategic KPI's",
#    'project_color': '0',
#    'project_hex_color': '#e36a00',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2362436338,
#    'pid': 179367366,
#    'tid': None,
#    'uid': 6700366,
#    'description': "Scoping Strategic KPI's",
#    'start': '2022-02-09T14:53:51+00:00',
#    'end': '2022-02-09T16:00:51+00:00',
#    'updated': '2022-02-10T07:41:26+00:00',
#    'dur': 4020000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': "Strategic KPI's",
#    'project_color': '0',
#    'project_hex_color': '#e36a00',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2362392429,
#    'pid': 179019829,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'PBI Support Corporate Sales Team',
#    'start': '2022-02-09T14:33:04+00:00',
#    'end': '2022-02-09T14:53:47+00:00',
#    'updated': '2022-02-09T14:53:47+00:00',
#    'dur': 1243000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'PBi Support',
#    'project_color': '0',
#    'project_hex_color': '#566614',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2362221391,
#    'pid': 179019829,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'PBI Support Suki Jira Dashboard',
#    'start': '2022-02-09T13:08:32+00:00',
#    'end': '2022-02-09T14:30:15+00:00',
#    'updated': '2022-02-09T14:30:16+00:00',
#    'dur': 4903000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'PBi Support',
#    'project_color': '0',
#    'project_hex_color': '#566614',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2362027254,
#    'pid': 179367366,
#    'tid': None,
#    'uid': 6700366,
#    'description': "Scoping Strategic KPI's",
#    'start': '2022-02-09T11:10:16+00:00',
#    'end': '2022-02-09T12:00:16+00:00',
#    'updated': '2022-02-09T13:08:23+00:00',
#    'dur': 3000000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': "Strategic KPI's",
#    'project_color': '0',
#    'project_hex_color': '#e36a00',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2361766503,
#    'pid': 179019829,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'PBI Governance',
#    'start': '2022-02-09T08:33:32+00:00',
#    'end': '2022-02-09T11:06:27+00:00',
#    'updated': '2022-02-09T11:06:27+00:00',
#    'dur': 9175000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'PBi Support',
#    'project_color': '0',
#    'project_hex_color': '#566614',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2361704996,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Locating GUS Salesforce Reports',
#    'start': '2022-02-09T07:56:16+00:00',
#    'end': '2022-02-09T08:33:32+00:00',
#    'updated': '2022-02-09T08:33:32+00:00',
#    'dur': 2236000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2360396122,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Sprint Retro',
#    'start': '2022-02-08T14:05:09+00:00',
#    'end': '2022-02-08T14:50:16+00:00',
#    'updated': '2022-02-08T14:50:15+00:00',
#    'dur': 2707000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2360291135,
#    'pid': 179019829,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'PBI Support Suki Jira Dashboard',
#    'start': '2022-02-08T13:00:37+00:00',
#    'end': '2022-02-08T14:05:08+00:00',
#    'updated': '2022-02-08T14:05:07+00:00',
#    'dur': 3871000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'PBi Support',
#    'project_color': '0',
#    'project_hex_color': '#566614',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2360028082,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'SF PBI Meeting',
#    'start': '2022-02-08T10:58:52+00:00',
#    'end': '2022-02-08T12:00:52+00:00',
#    'updated': '2022-02-08T13:23:03+00:00',
#    'dur': 3720000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2359989406,
#    'pid': 179019829,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'PBI Governance',
#    'start': '2022-02-08T10:34:36+00:00',
#    'end': '2022-02-08T10:58:37+00:00',
#    'updated': '2022-02-08T10:58:37+00:00',
#    'dur': 1441000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'PBi Support',
#    'project_color': '0',
#    'project_hex_color': '#566614',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2359979405,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'General admin',
#    'start': '2022-02-08T10:28:50+00:00',
#    'end': '2022-02-08T10:34:36+00:00',
#    'updated': '2022-02-08T10:34:36+00:00',
#    'dur': 346000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2359973753,
#    'pid': 179019829,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'PBI Governance',
#    'start': '2022-02-08T10:25:16+00:00',
#    'end': '2022-02-08T10:28:50+00:00',
#    'updated': '2022-02-08T10:28:50+00:00',
#    'dur': 214000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'PBi Support',
#    'project_color': '0',
#    'project_hex_color': '#566614',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2359952482,
#    'pid': 179004643,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'SITS Mig Support',
#    'start': '2022-02-08T10:11:54+00:00',
#    'end': '2022-02-08T10:22:55+00:00',
#    'updated': '2022-02-08T10:22:55+00:00',
#    'dur': 661000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'SITs Mig Dashboard',
#    'project_color': '0',
#    'project_hex_color': '#9e5bd9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2359888988,
#    'pid': 178668430,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'AST support',
#    'start': '2022-02-08T09:35:40+00:00',
#    'end': '2022-02-08T10:11:52+00:00',
#    'updated': '2022-02-08T10:11:52+00:00',
#    'dur': 2172000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'AST Revamp',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2359761101,
#    'pid': 179019829,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'PBI Governance',
#    'start': '2022-02-08T08:26:15+00:00',
#    'end': '2022-02-08T09:35:39+00:00',
#    'updated': '2022-02-08T09:35:40+00:00',
#    'dur': 4164000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'PBi Support',
#    'project_color': '0',
#    'project_hex_color': '#566614',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2359732175,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'General admin',
#    'start': '2022-02-08T07:30:02+00:00',
#    'end': '2022-02-08T08:26:14+00:00',
#    'updated': '2022-02-08T08:26:15+00:00',
#    'dur': 3372000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2358439002,
#    'pid': 179019829,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'PBI Governance',
#    'start': '2022-02-07T14:44:44+00:00',
#    'end': '2022-02-07T15:59:29+00:00',
#    'updated': '2022-02-07T15:59:29+00:00',
#    'dur': 4485000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'PBi Support',
#    'project_color': '0',
#    'project_hex_color': '#566614',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2358394215,
#    'pid': 178767529,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Self - Training ',
#    'start': '2022-02-07T14:25:35+00:00',
#    'end': '2022-02-07T14:44:43+00:00',
#    'updated': '2022-02-07T14:44:44+00:00',
#    'dur': 1148000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'Self',
#    'project_color': '0',
#    'project_hex_color': '#9e5bd9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2358253699,
#    'pid': 179019829,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'PBI Governance',
#    'start': '2022-02-07T13:21:35+00:00',
#    'end': '2022-02-07T14:25:20+00:00',
#    'updated': '2022-02-07T14:25:20+00:00',
#    'dur': 3825000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'PBi Support',
#    'project_color': '0',
#    'project_hex_color': '#566614',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2358042557,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'General admin',
#    'start': '2022-02-07T11:24:06+00:00',
#    'end': '2022-02-07T12:20:06+00:00',
#    'updated': '2022-02-07T13:21:10+00:00',
#    'dur': 3360000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2358024549,
#    'pid': 179286076,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Data Quality Dashboard',
#    'start': '2022-02-07T11:12:47+00:00',
#    'end': '2022-02-07T11:24:06+00:00',
#    'updated': '2022-02-07T11:24:01+00:00',
#    'dur': 679000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Data Quality DB',
#    'project_color': '0',
#    'project_hex_color': '#465bb3',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2357982438,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'General admin',
#    'start': '2022-02-07T10:49:54+00:00',
#    'end': '2022-02-07T11:12:03+00:00',
#    'updated': '2022-02-07T11:11:58+00:00',
#    'dur': 1329000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2357961941,
#    'pid': 178668430,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'AST support',
#    'start': '2022-02-07T10:39:14+00:00',
#    'end': '2022-02-07T10:49:51+00:00',
#    'updated': '2022-02-07T10:49:46+00:00',
#    'dur': 637000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'AST Revamp',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2357960828,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'General admin',
#    'start': '2022-02-07T10:38:32+00:00',
#    'end': '2022-02-07T10:39:14+00:00',
#    'updated': '2022-02-07T10:39:08+00:00',
#    'dur': 42000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2357947289,
#    'pid': 178668430,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'AST support',
#    'start': '2022-02-07T10:30:42+00:00',
#    'end': '2022-02-07T10:34:18+00:00',
#    'updated': '2022-02-07T10:34:12+00:00',
#    'dur': 216000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'AST Revamp',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2357805958,
#    'pid': 179019829,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'DAM KPIs',
#    'start': '2022-02-07T09:13:49+00:00',
#    'end': '2022-02-07T10:30:31+00:00',
#    'updated': '2022-02-07T10:30:26+00:00',
#    'dur': 4602000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'PBi Support',
#    'project_color': '0',
#    'project_hex_color': '#566614',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2357804924,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'General admin',
#    'start': '2022-02-07T08:50:16+00:00',
#    'end': '2022-02-07T09:13:16+00:00',
#    'updated': '2022-02-07T09:13:40+00:00',
#    'dur': 1380000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2357666163,
#    'pid': 179019829,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'DAM KPIs',
#    'start': '2022-02-07T07:30:55+00:00',
#    'end': '2022-02-07T08:50:55+00:00',
#    'updated': '2022-02-07T15:59:45+00:00',
#    'dur': 4800000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'PBi Support',
#    'project_color': '0',
#    'project_hex_color': '#566614',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2355603349,
#    'pid': 179019829,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'DAM KPIs',
#    'start': '2022-02-04T13:10:34+00:00',
#    'end': '2022-02-04T15:32:21+00:00',
#    'updated': '2022-02-04T15:32:23+00:00',
#    'dur': 8507000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'PBi Support',
#    'project_color': '0',
#    'project_hex_color': '#566614',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2355118585,
#    'pid': 178668430,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'AST Reporting build',
#    'start': '2022-02-04T07:42:40+00:00',
#    'end': '2022-02-04T12:00:40+00:00',
#    'updated': '2022-02-04T13:10:14+00:00',
#    'dur': 15480000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'AST Revamp',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2355096417,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'General admin',
#    'start': '2022-02-04T07:23:27+00:00',
#    'end': '2022-02-04T07:42:39+00:00',
#    'updated': '2022-02-04T07:42:41+00:00',
#    'dur': 1152000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2355095997,
#    'pid': 178668430,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'AST Reporting build',
#    'start': '2022-02-04T07:23:03+00:00',
#    'end': '2022-02-04T07:23:27+00:00',
#    'updated': '2022-02-04T07:23:28+00:00',
#    'dur': 24000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'AST Revamp',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2354071676,
#    'pid': 178668430,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'AST Reporting build',
#    'start': '2022-02-03T15:23:08+00:00',
#    'end': '2022-02-03T16:22:11+00:00',
#    'updated': '2022-02-03T16:22:12+00:00',
#    'dur': 3543000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'AST Revamp',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2353948500,
#    'pid': None,
#    'tid': None,
#    'uid': 6700366,
#    'description': '',
#    'start': '2022-02-03T14:26:16+00:00',
#    'end': '2022-02-03T15:23:08+00:00',
#    'updated': '2022-02-03T15:23:09+00:00',
#    'dur': 3412000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': None,
#    'project': None,
#    'project_color': '0',
#    'project_hex_color': None,
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2353842337,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'General admin',
#    'start': '2022-02-03T13:34:16+00:00',
#    'end': '2022-02-03T14:26:14+00:00',
#    'updated': '2022-02-03T14:26:14+00:00',
#    'dur': 3118000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2353662604,
#    'pid': 178668430,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'AST Reporting build',
#    'start': '2022-02-03T09:00:46+00:00',
#    'end': '2022-02-03T12:11:29+00:00',
#    'updated': '2022-02-03T12:11:31+00:00',
#    'dur': 11443000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'AST Revamp',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2353267244,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'General admin',
#    'start': '2022-02-03T07:30:51+00:00',
#    'end': '2022-02-03T09:00:51+00:00',
#    'updated': '2022-02-03T11:49:43+00:00',
#    'dur': 5400000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2352220068,
#    'pid': 179076630,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'DAM KPI meeting',
#    'start': '2022-02-02T15:00:27+00:00',
#    'end': '2022-02-02T15:46:37+00:00',
#    'updated': '2022-02-02T15:46:38+00:00',
#    'dur': 2770000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': "DAM KPI's",
#    'project_color': '0',
#    'project_hex_color': '#d94182',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2351915193,
#    'pid': 178668430,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'AST Reporting build',
#    'start': '2022-02-02T13:26:05+00:00',
#    'end': '2022-02-02T13:26:07+00:00',
#    'updated': '2022-02-02T13:26:07+00:00',
#    'dur': 2000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'AST Revamp',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2351915267,
#    'pid': 178668430,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'AST Reporting build',
#    'start': '2022-02-02T13:00:07+00:00',
#    'end': '2022-02-02T15:01:18+00:00',
#    'updated': '2022-02-02T15:01:19+00:00',
#    'dur': 7271000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'AST Revamp',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2351714313,
#    'pid': 178668430,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'AST Reporting build',
#    'start': '2022-02-02T11:28:52+00:00',
#    'end': '2022-02-02T12:00:52+00:00',
#    'updated': '2022-02-02T13:25:48+00:00',
#    'dur': 1920000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'AST Revamp',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2351666803,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'General admin',
#    'start': '2022-02-02T10:58:45+00:00',
#    'end': '2022-02-02T11:28:52+00:00',
#    'updated': '2022-02-02T11:28:52+00:00',
#    'dur': 1807000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2351600996,
#    'pid': 178668430,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'AST Reporting build',
#    'start': '2022-02-02T10:19:29+00:00',
#    'end': '2022-02-02T10:58:45+00:00',
#    'updated': '2022-02-02T10:58:45+00:00',
#    'dur': 2356000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'AST Revamp',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2351420297,
#    'pid': 179019829,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Class Disruption DB',
#    'start': '2022-02-02T08:35:04+00:00',
#    'end': '2022-02-02T10:19:09+00:00',
#    'updated': '2022-02-02T10:19:09+00:00',
#    'dur': 6245000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'PBi Support',
#    'project_color': '0',
#    'project_hex_color': '#566614',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []}]}

# %%
#request for second page of data
page_param2 = 'page=2'
combined_params2 = workspace_id_param+'&'+since_param+'&'+user_agent_param+'&'+page_param2
time_entries_page2 = requests.get(time_entries_url,headers=headers, params = combined_params2)
time_entries_data_page2 = time_entries_page2.json()
time_entries_data_page2
# Out:
# {'total_grand': 583420000,
#  'total_billable': None,
#  'total_currencies': [{'currency': None, 'amount': None}],
#  'total_count': 116,
#  'per_page': 50,
#  'data': [{'id': 2351314971,
#    'pid': 179004643,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'SITs Migration DB',
#    'start': '2022-02-02T07:24:40+00:00',
#    'end': '2022-02-02T08:35:00+00:00',
#    'updated': '2022-02-02T08:35:00+00:00',
#    'dur': 4220000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'SITs Mig Dashboard',
#    'project_color': '0',
#    'project_hex_color': '#9e5bd9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2350370564,
#    'pid': 179004643,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'SITs Migration DB',
#    'start': '2022-02-01T16:00:29+00:00',
#    'end': '2022-02-01T16:39:29+00:00',
#    'updated': '2022-02-01T16:39:45+00:00',
#    'dur': 2340000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'SITs Mig Dashboard',
#    'project_color': '0',
#    'project_hex_color': '#9e5bd9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2350102124,
#    'pid': 179019829,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Class Disruption DB',
#    'start': '2022-02-01T14:40:14+00:00',
#    'end': '2022-02-01T16:00:14+00:00',
#    'updated': '2022-02-01T16:39:23+00:00',
#    'dur': 4800000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'PBi Support',
#    'project_color': '0',
#    'project_hex_color': '#566614',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2350095354,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'General admin',
#    'start': '2022-02-01T14:37:10+00:00',
#    'end': '2022-02-01T14:40:00+00:00',
#    'updated': '2022-02-01T14:39:40+00:00',
#    'dur': 170000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2349860862,
#    'pid': 178668430,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'AST Reporting Catch up',
#    'start': '2022-02-01T12:48:46+00:00',
#    'end': '2022-02-01T13:20:46+00:00',
#    'updated': '2022-02-02T10:20:00+00:00',
#    'dur': 1920000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'AST Revamp',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2349774489,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Course Committee - PBI Solutions (Meeting)',
#    'start': '2022-02-01T11:59:09+00:00',
#    'end': '2022-02-01T12:48:33+00:00',
#    'updated': '2022-02-01T12:48:14+00:00',
#    'dur': 2964000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2349677604,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Sprint Planning/Finishing',
#    'start': '2022-02-01T10:59:50+00:00',
#    'end': '2022-02-01T11:58:38+00:00',
#    'updated': '2022-02-01T11:58:19+00:00',
#    'dur': 3528000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2349642264,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'General admin',
#    'start': '2022-02-01T10:20:32+00:00',
#    'end': '2022-02-01T10:59:36+00:00',
#    'updated': '2022-02-01T10:59:16+00:00',
#    'dur': 2344000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2349572274,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Scope meeting - Dot Dickson',
#    'start': '2022-02-01T09:58:30+00:00',
#    'end': '2022-02-01T10:20:30+00:00',
#    'updated': '2022-02-01T10:38:07+00:00',
#    'dur': 1320000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2349500274,
#    'pid': 179004643,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'SITs Migration DB',
#    'start': '2022-02-01T09:18:32+00:00',
#    'end': '2022-02-01T09:58:25+00:00',
#    'updated': '2022-02-01T09:58:05+00:00',
#    'dur': 2393000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'SITs Mig Dashboard',
#    'project_color': '0',
#    'project_hex_color': '#9e5bd9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2349434185,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'General admin',
#    'start': '2022-02-01T07:35:23+00:00',
#    'end': '2022-02-01T09:18:25+00:00',
#    'updated': '2022-02-01T09:18:05+00:00',
#    'dur': 6182000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2347728360,
#    'pid': None,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Build - Power Bi report for automated toggl invoicing',
#    'start': '2022-01-31T12:10:10+00:00',
#    'end': '2022-01-31T13:21:20+00:00',
#    'updated': '2022-01-31T13:21:18+00:00',
#    'dur': 4270000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': None,
#    'project': None,
#    'project_color': '0',
#    'project_hex_color': None,
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2347630793,
#    'pid': 178897182,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Toggl API dealing with paginated data',
#    'start': '2022-01-31T11:12:35+00:00',
#    'end': '2022-01-31T12:09:43+00:00',
#    'updated': '2022-01-31T12:09:41+00:00',
#    'dur': 3428000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'Toggl Tracker/Automated Invoicing',
#    'project_color': '0',
#    'project_hex_color': '#525266',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2347610450,
#    'pid': 178897182,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Toggl API Calling',
#    'start': '2022-01-31T10:23:55+00:00',
#    'end': '2022-01-31T11:12:18+00:00',
#    'updated': '2022-01-31T11:12:16+00:00',
#    'dur': 2903000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'Toggl Tracker/Automated Invoicing',
#    'project_color': '0',
#    'project_hex_color': '#525266',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2346651999,
#    'pid': 178897182,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Toggl API data to useable format',
#    'start': '2022-01-30T11:35:56+00:00',
#    'end': '2022-01-30T12:17:05+00:00',
#    'updated': '2022-01-30T12:17:04+00:00',
#    'dur': 2469000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'Toggl Tracker/Automated Invoicing',
#    'project_color': '0',
#    'project_hex_color': '#525266',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2346411641,
#    'pid': None,
#    'tid': None,
#    'uid': 6700366,
#    'description': '',
#    'start': '2022-01-29T18:11:02+00:00',
#    'end': '2022-01-29T18:47:52+00:00',
#    'updated': '2022-01-29T18:47:52+00:00',
#    'dur': 2210000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': None,
#    'project': None,
#    'project_color': '0',
#    'project_hex_color': None,
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2346314638,
#    'pid': 178897182,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Toggl API Calling',
#    'start': '2022-01-29T13:42:55+00:00',
#    'end': '2022-01-29T15:10:28+00:00',
#    'updated': '2022-01-29T15:10:28+00:00',
#    'dur': 5253000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'Toggl Tracker/Automated Invoicing',
#    'project_color': '0',
#    'project_hex_color': '#525266',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2346274155,
#    'pid': 178897182,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Toggl API Calling',
#    'start': '2022-01-29T11:28:48+00:00',
#    'end': '2022-01-29T12:36:44+00:00',
#    'updated': '2022-01-29T12:36:43+00:00',
#    'dur': 4076000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'Toggl Tracker/Automated Invoicing',
#    'project_color': '0',
#    'project_hex_color': '#525266',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2345433620,
#    'pid': 178897182,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Toggl API Calling',
#    'start': '2022-01-28T14:53:35+00:00',
#    'end': '2022-01-28T16:28:35+00:00',
#    'updated': '2022-01-29T11:28:37+00:00',
#    'dur': 5700000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'Toggl Tracker/Automated Invoicing',
#    'project_color': '0',
#    'project_hex_color': '#525266',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2339528968,
#    'pid': 178767529,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Net worth tracking',
#    'start': '2022-01-25T11:23:00+00:00',
#    'end': '2022-01-25T14:15:00+00:00',
#    'updated': '2022-01-28T14:53:14+00:00',
#    'dur': 10320000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'Self',
#    'project_color': '0',
#    'project_hex_color': '#9e5bd9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2338046349,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Class Disruption DB',
#    'start': '2022-01-24T15:30:06+00:00',
#    'end': '2022-01-24T16:01:45+00:00',
#    'updated': '2022-01-24T16:21:33+00:00',
#    'dur': 1899000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2337906610,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Admin email catch up',
#    'start': '2022-01-24T14:30:18+00:00',
#    'end': '2022-01-24T15:29:46+00:00',
#    'updated': '2022-01-24T15:29:38+00:00',
#    'dur': 3568000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2337735560,
#    'pid': 178720164,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'SITS Testing (Suki) Jira Reporting',
#    'start': '2022-01-24T13:10:27+00:00',
#    'end': '2022-01-24T14:30:11+00:00',
#    'updated': '2022-01-24T14:30:03+00:00',
#    'dur': 4784000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'SITs Testing Jira Reporting',
#    'project_color': '0',
#    'project_hex_color': '#c9806b',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2337339822,
#    'pid': 178720164,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'SITS Testing (Suki) Jira Reporting',
#    'start': '2022-01-24T09:22:59+00:00',
#    'end': '2022-01-24T13:10:11+00:00',
#    'updated': '2022-01-24T13:10:03+00:00',
#    'dur': 13632000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'SITs Testing Jira Reporting',
#    'project_color': '0',
#    'project_hex_color': '#c9806b',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2337330591,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Admin email catch up',
#    'start': '2022-01-24T09:17:59+00:00',
#    'end': '2022-01-24T09:22:59+00:00',
#    'updated': '2022-01-24T09:22:52+00:00',
#    'dur': 300000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2337329980,
#    'pid': 178720164,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'SITS Testing (Suki) Jira Reporting',
#    'start': '2022-01-24T09:17:39+00:00',
#    'end': '2022-01-24T09:17:58+00:00',
#    'updated': '2022-01-24T09:17:51+00:00',
#    'dur': 19000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'SITs Testing Jira Reporting',
#    'project_color': '0',
#    'project_hex_color': '#c9806b',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2337270646,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Morning Meetings',
#    'start': '2022-01-24T08:46:18+00:00',
#    'end': '2022-01-24T09:17:31+00:00',
#    'updated': '2022-01-24T09:17:23+00:00',
#    'dur': 1873000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2337219579,
#    'pid': 178720164,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'SITS Testing (Suki) Jira Reporting',
#    'start': '2022-01-24T08:16:40+00:00',
#    'end': '2022-01-24T08:46:02+00:00',
#    'updated': '2022-01-24T08:45:54+00:00',
#    'dur': 1762000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'SITs Testing Jira Reporting',
#    'project_color': '0',
#    'project_hex_color': '#c9806b',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2337171145,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Admin email catch up',
#    'start': '2022-01-24T07:30:57+00:00',
#    'end': '2022-01-24T08:16:40+00:00',
#    'updated': '2022-01-24T08:16:32+00:00',
#    'dur': 2743000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2335245794,
#    'pid': 178675988,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Jira reporting for rob',
#    'start': '2022-01-21T13:39:53+00:00',
#    'end': '2022-01-21T15:50:00+00:00',
#    'updated': '2022-01-21T16:01:20+00:00',
#    'dur': 7807000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Jira reporting',
#    'project_color': '0',
#    'project_hex_color': '#d94182',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2335242391,
#    'pid': 178675975,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Corporate pbi support',
#    'start': '2022-01-21T13:00:00+00:00',
#    'end': '2022-01-21T13:38:30+00:00',
#    'updated': '2022-01-21T13:39:50+00:00',
#    'dur': 2310000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Corporate app dashboard',
#    'project_color': '0',
#    'project_hex_color': '#e36a00',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334763430,
#    'pid': 178668430,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'AST reporting revamp',
#    'start': '2022-01-21T08:19:00+00:00',
#    'end': '2022-01-21T12:14:00+00:00',
#    'updated': '2022-01-21T13:38:25+00:00',
#    'dur': 14100000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'AST Revamp',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334762556,
#    'pid': 178668409,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'General admin',
#    'start': '2022-01-21T07:30:34+00:00',
#    'end': '2022-01-21T08:19:00+00:00',
#    'updated': '2022-01-21T08:20:44+00:00',
#    'dur': 2906000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'Arden University',
#    'project': 'Arden Uni General',
#    'project_color': '0',
#    'project_hex_color': '#0b83d9',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334193943,
#    'pid': 178651855,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Exporting data with python through Toggl API',
#    'start': '2022-01-20T20:31:31+00:00',
#    'end': '2022-01-20T22:39:58+00:00',
#    'updated': '2022-01-21T08:22:16+00:00',
#    'dur': 7707000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'ABC - Finance',
#    'project': 'ABC Toggl Tracker',
#    'project_color': '0',
#    'project_hex_color': '#2da608',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334190852,
#    'pid': 178651855,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Populating Data',
#    'start': '2022-01-20T20:29:21+00:00',
#    'end': '2022-01-20T20:31:14+00:00',
#    'updated': '2022-01-20T20:31:14+00:00',
#    'dur': 113000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'ABC - Finance',
#    'project': 'ABC Toggl Tracker',
#    'project_color': '0',
#    'project_hex_color': '#2da608',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334138080,
#    'pid': 178651855,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Initial Client Meeting',
#    'start': '2022-01-20T19:49:03+00:00',
#    'end': '2022-01-20T20:29:16+00:00',
#    'updated': '2022-01-21T08:22:25+00:00',
#    'dur': 2413000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'ABC - Finance',
#    'project': 'ABC Toggl Tracker',
#    'project_color': '0',
#    'project_hex_color': '#2da608',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334064647,
#    'pid': 178651855,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Populating Data',
#    'start': '2022-01-20T18:55:52+00:00',
#    'end': '2022-01-20T19:48:51+00:00',
#    'updated': '2022-01-20T19:48:51+00:00',
#    'dur': 3179000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'ABC - Finance',
#    'project': 'ABC Toggl Tracker',
#    'project_color': '0',
#    'project_hex_color': '#2da608',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334064114,
#    'pid': 178651855,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Populating Data',
#    'start': '2022-01-20T18:55:29+00:00',
#    'end': '2022-01-20T18:55:42+00:00',
#    'updated': '2022-01-20T18:55:50+00:00',
#    'dur': 13000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'ABC - Finance',
#    'project': 'ABC Toggl Tracker',
#    'project_color': '0',
#    'project_hex_color': '#2da608',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334040588,
#    'pid': 178651855,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Scope - Toggl Tracker',
#    'start': '2022-01-20T18:38:17+00:00',
#    'end': '2022-01-20T18:44:27+00:00',
#    'updated': '2022-01-20T18:44:36+00:00',
#    'dur': 370000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'ABC - Finance',
#    'project': 'ABC Toggl Tracker',
#    'project_color': '0',
#    'project_hex_color': '#2da608',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126182,
#    'pid': 178654084,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Training Team Leads',
#    'start': '2021-11-19T15:23:00+00:00',
#    'end': '2021-11-19T16:48:22+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 5122000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'SW Learning - Portfolio',
#    'project_color': '0',
#    'project_hex_color': '#465bb3',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126181,
#    'pid': 178654084,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Training Super users',
#    'start': '2021-11-16T11:54:00+00:00',
#    'end': '2021-11-16T15:16:05+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 12125000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'SW Learning - Portfolio',
#    'project_color': '0',
#    'project_hex_color': '#465bb3',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126180,
#    'pid': 178654084,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Presentation to SLT',
#    'start': '2021-11-13T14:22:00+00:00',
#    'end': '2021-11-13T19:36:55+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 18895000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'SW Learning - Portfolio',
#    'project_color': '0',
#    'project_hex_color': '#465bb3',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126178,
#    'pid': 178654084,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Delivery',
#    'start': '2021-11-10T15:23:00+00:00',
#    'end': '2021-11-10T16:21:25+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 3505000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'SW Learning - Portfolio',
#    'project_color': '0',
#    'project_hex_color': '#465bb3',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126177,
#    'pid': 178654084,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Presentation to Arno + Team',
#    'start': '2021-11-07T11:54:00+00:00',
#    'end': '2021-11-07T16:15:33+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 15693000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'SW Learning - Portfolio',
#    'project_color': '0',
#    'project_hex_color': '#465bb3',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126176,
#    'pid': 178654084,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Delivery',
#    'start': '2021-11-04T10:23:52+00:00',
#    'end': '2021-11-04T12:36:47+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 7975000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'SW Learning - Portfolio',
#    'project_color': '0',
#    'project_hex_color': '#465bb3',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126175,
#    'pid': 178654084,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Meeting With Arno',
#    'start': '2021-11-01T10:23:52+00:00',
#    'end': '2021-11-01T11:49:14+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 5122000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'SW Learning - Portfolio',
#    'project_color': '0',
#    'project_hex_color': '#465bb3',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126174,
#    'pid': 178654084,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Feedback Tasks',
#    'start': '2021-10-29T17:00:00+00:00',
#    'end': '2021-10-29T19:12:55+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 7975000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'SW Learning - Portfolio',
#    'project_color': '0',
#    'project_hex_color': '#465bb3',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126172,
#    'pid': 178654084,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Visualisation',
#    'start': '2021-10-26T08:14:00+00:00',
#    'end': '2021-10-26T09:12:25+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 3505000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'SW Learning - Portfolio',
#    'project_color': '0',
#    'project_hex_color': '#465bb3',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126171,
#    'pid': 178654084,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Validating',
#    'start': '2021-10-23T14:22:00+00:00',
#    'end': '2021-10-23T18:43:33+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 15693000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'SW Learning - Portfolio',
#    'project_color': '0',
#    'project_hex_color': '#465bb3',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []},
#   {'id': 2334126170,
#    'pid': 178654084,
#    'tid': None,
#    'uid': 6700366,
#    'description': 'Initial Code',
#    'start': '2021-10-20T15:23:00+00:00',
#    'end': '2021-10-20T16:21:25+00:00',
#    'updated': '2022-01-20T19:39:53+00:00',
#    'dur': 3505000,
#    'user': 'Mark Clipsham',
#    'use_stop': True,
#    'client': 'SW - Learning',
#    'project': 'SW Learning - Portfolio',
#    'project_color': '0',
#    'project_hex_color': '#465bb3',
#    'task': None,
#    'billable': None,
#    'is_billable': False,
#    'cur': None,
#    'tags': []}]}

# %%
#converting returned data to pandas dataframe
data_page1 = time_entries_data_page1['data']
df_page1 = pd.DataFrame(data_page1)
data_page2 = time_entries_data_page2['data']
df_page2 = pd.DataFrame(data_page2)

#dropping un-used columns
df_page1 = df_page1.drop(columns=['use_stop', 'task', 'billable', 'is_billable', 'cur', 'tags','project_color'])
df_page2 = df_page2.drop(columns=['use_stop', 'task', 'billable', 'is_billable', 'cur', 'tags','project_color'])

# %%
#appending pages into a single dataframe
data = df_page1.append(df_page2, ignore_index=True)
data
# Out:
#             id          pid   tid      uid  \
# 0   2364428553  179019829.0  None  6700366
# 1   2364368122  178675988.0  None  6700366
# 2   2364367209  179367366.0  None  6700366
# 3   2363666000  179367366.0  None  6700366
# 4   2363649397  178675988.0  None  6700366
# ..         ...          ...   ...      ...
# 95  2334126175  178654084.0  None  6700366
# 96  2334126174  178654084.0  None  6700366
# 97  2334126172  178654084.0  None  6700366
# 98  2334126171  178654084.0  None  6700366
# 99  2334126170  178654084.0  None  6700366
#
#                                     description                      start  \
# 0   Scoping Automated Finance Snapshot Solution  2022-02-10T15:36:51+00:00
# 1                 Long term Jira Reporting Plan  2022-02-10T15:07:35+00:00
# 2                       Scoping Strategic KPI's  2022-02-10T13:00:07+00:00
# 3                       Scoping Strategic KPI's  2022-02-10T08:29:28+00:00
# 4                 Long term Jira Reporting Plan  2022-02-10T08:18:48+00:00
# ..                                          ...                        ...
# 95                            Meeting With Arno  2021-11-01T10:23:52+00:00
# 96                               Feedback Tasks  2021-10-29T17:00:00+00:00
# 97                                Visualisation  2021-10-26T08:14:00+00:00
# 98                                   Validating  2021-10-23T14:22:00+00:00
# 99                                 Initial Code  2021-10-20T15:23:00+00:00
#
#                           end                    updated       dur  \
# 0   2022-02-10T16:03:08+00:00  2022-02-10T16:03:07+00:00   1577000
# 1   2022-02-10T15:36:39+00:00  2022-02-10T15:36:37+00:00   1744000
# 2   2022-02-10T15:07:07+00:00  2022-02-10T15:07:19+00:00   7620000
# 3   2022-02-10T12:00:28+00:00  2022-02-10T15:06:47+00:00  12660000
# 4   2022-02-10T08:29:28+00:00  2022-02-10T08:29:25+00:00    640000
# ..                        ...                        ...       ...
# 95  2021-11-01T11:49:14+00:00  2022-01-20T19:39:53+00:00   5122000
# 96  2021-10-29T19:12:55+00:00  2022-01-20T19:39:53+00:00   7975000
# 97  2021-10-26T09:12:25+00:00  2022-01-20T19:39:53+00:00   3505000
# 98  2021-10-23T18:43:33+00:00  2022-01-20T19:39:53+00:00  15693000
# 99  2021-10-20T16:21:25+00:00  2022-01-20T19:39:53+00:00   3505000
#
#              user            client                  project project_hex_color
# 0   Mark Clipsham  Arden University              PBi Support           #566614
# 1   Mark Clipsham  Arden University           Jira reporting           #d94182
# 2   Mark Clipsham  Arden University          Strategic KPI's           #e36a00
# 3   Mark Clipsham  Arden University          Strategic KPI's           #e36a00
# 4   Mark Clipsham  Arden University           Jira reporting           #d94182
# ..            ...               ...                      ...               ...
# 95  Mark Clipsham     SW - Learning  SW Learning - Portfolio           #465bb3
# 96  Mark Clipsham     SW - Learning  SW Learning - Portfolio           #465bb3
# 97  Mark Clipsham     SW - Learning  SW Learning - Portfolio           #465bb3
# 98  Mark Clipsham     SW - Learning  SW Learning - Portfolio           #465bb3
# 99  Mark Clipsham     SW - Learning  SW Learning - Portfolio           #465bb3
#
# [100 rows x 13 columns]

# %%
#pandas dataframe to csv file
csv = data.to_csv(r'C:\Users\markr\Documents\Portfolio\Toggl Tracker\output.csv')
